# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-90.000,high=90.000,size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | agadez
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | bialogard
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | bayan
# Processing Record 9 of Set 1 | asfi
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | bandarbeyla
# Processing Record 14 of Set 1 | manadhoo
# Processing Record 15 of Set 1 | port hawkesbury
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | tevriz
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | tsogni
# Processing Record 21 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | bubaque
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | marsa matruh
# Processing Record 31 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 1 | wagar
# Processing Record 33 of Set 1 | maracaju
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | rosetta
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | paralimni
# Processing Record 39 of Set 1 | olafsvik
# Processing Record 40 of Set 1 | vila velha
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | margate
# Processing Record 43 of Set 1 | tiznit
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | henties bay
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | lolodorf
# Processing Record 49 of Set 1 | meulaboh
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | jalu
# Processing Record 2 of Set 2 | kavaratti
# Processing Record 3 of Set 2 | tazovskiy
# Processing Record 4 of Set 2 | kinango
# Processing Record 5 of Set 2 | puerto leguizamo
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | kharp
# Processing Record 9 of Set 2 | oussouye
# Processing Record 10 of Set 2 | san cristobal
# Processing Record 11 of Set 2 | mossendjo
# Processing Record 12 of Set 2 | bihar
# Processing Record 13 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | nampula
# Processing Record 16 of Set 2 | laguna
# Processing Record 17 of Set 2 | mehamn
# Processing Record 18 of Set 2 | parana
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | kudahuvadhoo
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | beni suef
# Processing Record 23 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 2 | mathathane
# Processing Record 25 of Set 2 | mbaiki
# Processing Record 26 of Set 2 | borda da mata
# Processing Record 27 of Set 2 | gulfport
# Processing Record 28 of Set 2 | camana
# Processing Record 29 of Set 2 | marathon
# Processing Record 30 of Set 2 | acarau
# Processing Record 31 of Set 2 | sao joao da barra
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | nouadhibou
# Processing Record 34 of Set 2 | grand baie
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | ugoofaaru
# Processing Record 37 of Set 2 | codrington
# Processing Record 38 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 2 | pinjaur
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | sao miguel
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | luziania
# Processing Record 44 of Set 2 | rincon
# Processing Record 45 of Set 2 | vila franca do campo
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | umm kaddadah
# Processing Record 48 of Set 2 | arlit
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | kulebaki
# Processing Record 1 of Set 3 | muhos
# Processing Record 2 of Set 3 | zheleznodorozhnyy
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | iskateley
# Processing Record 5 of Set 3 | kamenka
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | pietersburg
# Processing Record 8 of Set 3 | douentza
# Processing Record 9 of Set 3 | comodoro rivadavia
# Processing Record 10 of Set 3 | antalaha
# Processing Record 11 of Set 3 | leshukonskoye
# Processing Record 12 of Set 3 | verkhoturye
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 3 | pitimbu
# Processing Record 16 of Set 3 | eirunepe
# Processing Record 17 of Set 3 | buenos aires
# Processing Record 18 of Set 3 | mataruska banja
# Processing Record 19 of Set 3 | salym
# Processing Record 20 of Set 3 | mekhe
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | san luis
# Processing Record 23 of Set 3 | narsaq
# Processing Record 24 of Set 3 | szentistvan
# Processing Record 25 of Set 3 | saalfelden
# City not found. Skipping...
# Processing Record 26 of Set 3 | bonthe
# Processing Record 27 of Set 3 | sao jose da coroa grande
# Processing Record 28 of Set 3 | dwarka
# Processing Record 29 of Set 3 | alto araguaia
# Processing Record 30 of Set 3 | zhanaozen
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | hvittingfoss
# Processing Record 33 of Set 3 | gat
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 3 | handwara
# City not found. Skipping...
# Processing Record 37 of Set 3 | latur
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | vagur
# Processing Record 40 of Set 3 | tabatinga
# Processing Record 41 of Set 3 | manta
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 3 | bayir
# Processing Record 46 of Set 3 | boende
# Processing Record 47 of Set 3 | saint-augustin
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | male
# Processing Record 50 of Set 3 | rawson
# Processing Record 1 of Set 4 | mana
# Processing Record 2 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 5 of Set 4 | urengoy
# Processing Record 6 of Set 4 | coihaique
# Processing Record 7 of Set 4 | aksu
# Processing Record 8 of Set 4 | paamiut
# Processing Record 9 of Set 4 | huntsville
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | coquimbo
# Processing Record 12 of Set 4 | hofn
# Processing Record 13 of Set 4 | korla
# Processing Record 14 of Set 4 | lagoa
# Processing Record 15 of Set 4 | ilhabela
# Processing Record 16 of Set 4 | santiago
# Processing Record 17 of Set 4 | bollnas
# Processing Record 18 of Set 4 | nsanje
# Processing Record 19 of Set 4 | sorland
# Processing Record 20 of Set 4 | iturama
# Processing Record 21 of Set 4 | agadir
# Processing Record 22 of Set 4 | krasnoselkup
# Processing Record 23 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 4 | narok
# Processing Record 25 of Set 4 | hit
# Processing Record 26 of Set 4 | arraial do cabo
# Processing Record 27 of Set 4 | rocha
# Processing Record 28 of Set 4 | darab
# Processing Record 29 of Set 4 | sulurpeta
# City not found. Skipping...
# Processing Record 30 of Set 4 | beloha
# Processing Record 31 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 | galway
# Processing Record 34 of Set 4 | hrodna
# Processing Record 35 of Set 4 | moose factory
# Processing Record 36 of Set 4 | little current
# Processing Record 37 of Set 4 | faya
# Processing Record 38 of Set 4 | arona
# Processing Record 39 of Set 4 | bolobo
# Processing Record 40 of Set 4 | mayumba
# Processing Record 41 of Set 4 | maceio
# Processing Record 42 of Set 4 | novoomskiy
# Processing Record 43 of Set 4 | eyl
# Processing Record 44 of Set 4 | mangai
# Processing Record 45 of Set 4 | abu samrah
# Processing Record 46 of Set 4 | tambovka
# Processing Record 47 of Set 4 | virginia beach
# Processing Record 48 of Set 4 | nushki
# Processing Record 49 of Set 4 | kastamonu
# Processing Record 50 of Set 4 | kindia
# Processing Record 1 of Set 5 | bangangte
# Processing Record 2 of Set 5 | sylacauga
# Processing Record 3 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | constantine
# Processing Record 7 of Set 5 | blagoveshchensk
# Processing Record 8 of Set 5 | riyadh
# Processing Record 9 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 10 of Set 5 | saint anthony
# Processing Record 11 of Set 5 | rio grande
# Processing Record 12 of Set 5 | brae
# Processing Record 13 of Set 5 | santa fe
# Processing Record 14 of Set 5 | mega
# Processing Record 15 of Set 5 | biltine
# Processing Record 16 of Set 5 | nurota
# Processing Record 17 of Set 5 | praia
# Processing Record 18 of Set 5 | hammerfest
# Processing Record 19 of Set 5 | sisimiut
# Processing Record 20 of Set 5 | inverness
# Processing Record 21 of Set 5 | sabang
# Processing Record 22 of Set 5 | fort-shevchenko
# Processing Record 23 of Set 5 | ostrovnoy
# Processing Record 24 of Set 5 | richards bay
# Processing Record 25 of Set 5 | sargatskoye
# Processing Record 26 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 27 of Set 5 | labytnangi
# Processing Record 28 of Set 5 | bongandanga
# Processing Record 29 of Set 5 | talcahuano
# Processing Record 30 of Set 5 | itarema
# Processing Record 31 of Set 5 | abha
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | akureyri
# Processing Record 36 of Set 5 | carutapera
# Processing Record 37 of Set 5 | shostka
# Processing Record 38 of Set 5 | escanaba
# Processing Record 39 of Set 5 | tasiilaq
# Processing Record 40 of Set 5 | outjo
# Processing Record 41 of Set 5 | poiana mare
# Processing Record 42 of Set 5 | beyneu
# Processing Record 43 of Set 5 | minab
# Processing Record 44 of Set 5 | cabedelo
# Processing Record 45 of Set 5 | otavalo
# Processing Record 46 of Set 5 | dakoro
# Processing Record 47 of Set 5 | ornskoldsvik
# Processing Record 48 of Set 5 | san-pedro
# Processing Record 49 of Set 5 | galle
# Processing Record 50 of Set 5 | maloy
# Processing Record 1 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 6 | kulhudhuffushi
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | treuchtlingen
# Processing Record 5 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 6 | pokhara
# Processing Record 7 of Set 6 | cururupu
# Processing Record 8 of Set 6 | hambantota
# Processing Record 9 of Set 6 | killybegs
# Processing Record 10 of Set 6 | nchelenge
# Processing Record 11 of Set 6 | maridi
# Processing Record 12 of Set 6 | vestmanna
# Processing Record 13 of Set 6 | karasjok
# Processing Record 14 of Set 6 | castro
# Processing Record 15 of Set 6 | hauterive
# Processing Record 16 of Set 6 | aksarka
# Processing Record 17 of Set 6 | sandovo
# Processing Record 18 of Set 6 | buta
# Processing Record 19 of Set 6 | synya
# Processing Record 20 of Set 6 | pombas
# Processing Record 21 of Set 6 | chikwawa
# Processing Record 22 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 6 | gravenhurst
# Processing Record 24 of Set 6 | toulepleu
# City not found. Skipping...
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | atar
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | kalmanka
# Processing Record 29 of Set 6 | asosa
# Processing Record 30 of Set 6 | elat
# Processing Record 31 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 32 of Set 6 | maragogi
# Processing Record 33 of Set 6 | gornyy
# Processing Record 34 of Set 6 | novopokrovka
# Processing Record 35 of Set 6 | rio gallegos
# Processing Record 36 of Set 6 | petrovskoye
# Processing Record 37 of Set 6 | breves
# Processing Record 38 of Set 6 | chicama
# Processing Record 39 of Set 6 | ambilobe
# Processing Record 40 of Set 6 | joshimath
# Processing Record 41 of Set 6 | machali
# Processing Record 42 of Set 6 | obligado
# Processing Record 43 of Set 6 | uige
# Processing Record 44 of Set 6 | iranshahr
# Processing Record 45 of Set 6 | andilamena
# Processing Record 46 of Set 6 | harper
# Processing Record 47 of Set 6 | axim
# Processing Record 48 of Set 6 | bambous virieux
# Processing Record 49 of Set 6 | old shinyanga
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | mahajanga
# Processing Record 2 of Set 7 | batsfjord
# Processing Record 3 of Set 7 | sayville
# Processing Record 4 of Set 7 | sur
# Processing Record 5 of Set 7 | esmeralda
# Processing Record 6 of Set 7 | banyo
# Processing Record 7 of Set 7 | beruwala
# Processing Record 8 of Set 7 | cedar lake
# Processing Record 9 of Set 7 | shubarshi
# Processing Record 10 of Set 7 | myre
# Processing Record 11 of Set 7 | salalah
# Processing Record 12 of Set 7 | khash
# Processing Record 13 of Set 7 | cayenne
# Processing Record 14 of Set 7 | baghdad
# Processing Record 15 of Set 7 | andenes
# Processing Record 16 of Set 7 | mokrousovo
# Processing Record 17 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 7 | taormina
# Processing Record 19 of Set 7 | edd
# Processing Record 20 of Set 7 | georgiyevskoye
# Processing Record 21 of Set 7 | concarneau
# Processing Record 22 of Set 7 | filadelfia
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | itaperucu
# Processing Record 25 of Set 7 | tricase
# Processing Record 26 of Set 7 | znamenskoye
# Processing Record 27 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 7 | grand gaube
# Processing Record 29 of Set 7 | mahon
# Processing Record 30 of Set 7 | oswego
# Processing Record 31 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 7 | la rioja
# Processing Record 33 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | belmonte
# Processing Record 36 of Set 7 | constitucion
# Processing Record 37 of Set 7 | benguela
# Processing Record 38 of Set 7 | tobol
# Processing Record 39 of Set 7 | pimentel
# Processing Record 40 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 41 of Set 7 | taltal
# Processing Record 42 of Set 7 | canguaretama
# Processing Record 43 of Set 7 | kargil
# Processing Record 44 of Set 7 | neyshabur
# Processing Record 45 of Set 7 | nioro
# Processing Record 46 of Set 7 | coracora
# Processing Record 47 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | picui
# Processing Record 50 of Set 7 | kismayo
# Processing Record 1 of Set 8 | inzer
# Processing Record 2 of Set 8 | yangambi
# Processing Record 3 of Set 8 | igarka
# Processing Record 4 of Set 8 | castel san giovanni
# Processing Record 5 of Set 8 | tessalit
# Processing Record 6 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 8 | wajir
# Processing Record 8 of Set 8 | lomovka
# Processing Record 9 of Set 8 | saint-jean-de-maurienne
# Processing Record 10 of Set 8 | licata
# Processing Record 11 of Set 8 | altagracia de orituco
# Processing Record 12 of Set 8 | corinth
# Processing Record 13 of Set 8 | kidal
# Processing Record 14 of Set 8 | montepuez
# Processing Record 15 of Set 8 | parvatipuram
# Processing Record 16 of Set 8 | saurimo
# Processing Record 17 of Set 8 | zakopane
# Processing Record 18 of Set 8 | manicore
# Processing Record 19 of Set 8 | boddam
# Processing Record 20 of Set 8 | sarakhs
# Processing Record 21 of Set 8 | anniston
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | bernal
# Processing Record 24 of Set 8 | mandera
# Processing Record 25 of Set 8 | verkhnyaya inta
# Processing Record 26 of Set 8 | samoded
# Processing Record 27 of Set 8 | saint-louis
# Processing Record 28 of Set 8 | huamachuco
# Processing Record 29 of Set 8 | toguchin
# Processing Record 30 of Set 8 | algarrobo
# Processing Record 31 of Set 8 | izmit
# Processing Record 32 of Set 8 | ushtobe
# Processing Record 33 of Set 8 | floro
# Processing Record 34 of Set 8 | sao jose dos campos
# Processing Record 35 of Set 8 | porto belo
# Processing Record 36 of Set 8 | ambatofinandrahana
# Processing Record 37 of Set 8 | maunabo
# Processing Record 38 of Set 8 | elbistan
# Processing Record 39 of Set 8 | grand-bourg
# Processing Record 40 of Set 8 | bathsheba
# Processing Record 41 of Set 8 | sawai madhopur
# Processing Record 42 of Set 8 | lima
# Processing Record 43 of Set 8 | pisz
# Processing Record 44 of Set 8 | burica
# City not found. Skipping...
# Processing Record 45 of Set 8 | bestobe
# Processing Record 46 of Set 8 | den helder
# Processing Record 47 of Set 8 | jijiga
# Processing Record 48 of Set 8 | isetskoye
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | belmopan
# Processing Record 1 of Set 9 | sioux lookout
# Processing Record 2 of Set 9 | aswan
# Processing Record 3 of Set 9 | pangnirtung
# Processing Record 4 of Set 9 | berbera
# Processing Record 5 of Set 9 | adwa
# Processing Record 6 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 9 | coleraine
# Processing Record 8 of Set 9 | parczew
# Processing Record 9 of Set 9 | sturgeon falls
# Processing Record 10 of Set 9 | hosur
# Processing Record 11 of Set 9 | kangaatsiaq
# Processing Record 12 of Set 9 | fowa
# Processing Record 13 of Set 9 | pout
# Processing Record 14 of Set 9 | bondo
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | takoradi
# Processing Record 17 of Set 9 | road town
# Processing Record 18 of Set 9 | toronto
# Processing Record 19 of Set 9 | mesyagutovo
# Processing Record 20 of Set 9 | adre
# Processing Record 21 of Set 9 | snezhnogorsk
# Processing Record 22 of Set 9 | zhob
# Processing Record 23 of Set 9 | ginda
# Processing Record 24 of Set 9 | paranapanema
# Processing Record 25 of Set 9 | tukrah
# Processing Record 26 of Set 9 | solenzo
# Processing Record 27 of Set 9 | luanda
# Processing Record 28 of Set 9 | trinidad
# Processing Record 29 of Set 9 | talara
# Processing Record 30 of Set 9 | kuusamo
# Processing Record 31 of Set 9 | chulym
# Processing Record 32 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 9 | maine-soroa
# Processing Record 34 of Set 9 | morros
# Processing Record 35 of Set 9 | timizart
# Processing Record 36 of Set 9 | porosozero
# Processing Record 37 of Set 9 | inhambane
# Processing Record 38 of Set 9 | tolmachevo
# Processing Record 39 of Set 9 | thunder bay
# Processing Record 40 of Set 9 | balkhash
# Processing Record 41 of Set 9 | riviere-au-renard
# Processing Record 42 of Set 9 | diourbel
# Processing Record 43 of Set 9 | belyy yar
# Processing Record 44 of Set 9 | ouro preto do oeste
# Processing Record 45 of Set 9 | roald
# Processing Record 46 of Set 9 | ipixuna
# Processing Record 47 of Set 9 | cap malheureux
# Processing Record 48 of Set 9 | alunitdag
# City not found. Skipping...
# Processing Record 49 of Set 9 | kedrovyy
# Processing Record 50 of Set 9 | jumla
# Processing Record 1 of Set 10 | port-cartier
# Processing Record 2 of Set 10 | port-gentil
# Processing Record 3 of Set 10 | hilpoltstein
# Processing Record 4 of Set 10 | raudeberg
# Processing Record 5 of Set 10 | bahia blanca
# Processing Record 6 of Set 10 | sol-iletsk
# Processing Record 7 of Set 10 | boma
# Processing Record 8 of Set 10 | azul
# Processing Record 9 of Set 10 | sosnovka
# Processing Record 10 of Set 10 | cockburn town
# Processing Record 11 of Set 10 | chapleau
# Processing Record 12 of Set 10 | tonj
# Processing Record 13 of Set 10 | nuuk
# Processing Record 14 of Set 10 | jamalpur
# Processing Record 15 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 10 | soyo
# Processing Record 17 of Set 10 | toksovo
# Processing Record 18 of Set 10 | klaksvik
# Processing Record 19 of Set 10 | brzeg
# Processing Record 20 of Set 10 | saint-pierre
# Processing Record 21 of Set 10 | colares
# Processing Record 22 of Set 10 | chichli
# Processing Record 23 of Set 10 | puerto ayora
# Processing Record 24 of Set 10 | tombouctou
# Processing Record 25 of Set 10 | monrovia
# Processing Record 26 of Set 10 | candolim
# Processing Record 27 of Set 10 | hualmay
# Processing Record 28 of Set 10 | liverpool
# Processing Record 29 of Set 10 | pergine valsugana
# Processing Record 30 of Set 10 | xuddur
# Processing Record 31 of Set 10 | tabou
# Processing Record 32 of Set 10 | anupgarh
# Processing Record 33 of Set 10 | trelew
# Processing Record 34 of Set 10 | taraz
# Processing Record 35 of Set 10 | praia da vitoria
# Processing Record 36 of Set 10 | aljezur
# Processing Record 37 of Set 10 | serenje
# Processing Record 38 of Set 10 | maniitsoq
# Processing Record 39 of Set 10 | stavern
# Processing Record 40 of Set 10 | porto novo
# Processing Record 41 of Set 10 | kholm-zhirkovskiy
# Processing Record 42 of Set 10 | toledo
# Processing Record 43 of Set 10 | rabo de peixe
# Processing Record 44 of Set 10 | hurghada
# Processing Record 45 of Set 10 | mbandaka
# Processing Record 46 of Set 10 | spremberg
# Processing Record 47 of Set 10 | chalmette
# Processing Record 48 of Set 10 | badami
# Processing Record 49 of Set 10 | una
# Processing Record 50 of Set 10 | miquelon
# Processing Record 1 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 11 | salaberry-de-valleyfield
# Processing Record 3 of Set 11 | arrecife
# Processing Record 4 of Set 11 | north myrtle beach
# Processing Record 5 of Set 11 | qasigiannguit
# Processing Record 6 of Set 11 | rock falls
# Processing Record 7 of Set 11 | nantucket
# Processing Record 8 of Set 11 | droitwich
# Processing Record 9 of Set 11 | amapa
# Processing Record 10 of Set 11 | vamdrup
# Processing Record 11 of Set 11 | bage
# Processing Record 12 of Set 11 | quatre cocos
# Processing Record 13 of Set 11 | eldorado
# Processing Record 14 of Set 11 | brattleboro
# Processing Record 15 of Set 11 | olinda
# Processing Record 16 of Set 11 | mulchen
# Processing Record 17 of Set 11 | kvarkeno
# Processing Record 18 of Set 11 | carballo
# Processing Record 19 of Set 11 | sao gabriel da cachoeira
# Processing Record 20 of Set 11 | aranos
# Processing Record 21 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 11 | krouson
# Processing Record 23 of Set 11 | bafoulabe
# Processing Record 24 of Set 11 | birao
# Processing Record 25 of Set 11 | sayyan
# Processing Record 26 of Set 11 | ballina
# Processing Record 27 of Set 11 | chipinge
# Processing Record 28 of Set 11 | urumqi
# Processing Record 29 of Set 11 | gorgan
# Processing Record 30 of Set 11 | kouango
# Processing Record 31 of Set 11 | jaisalmer
# Processing Record 32 of Set 11 | guiratinga
# Processing Record 33 of Set 11 | aden
# Processing Record 34 of Set 11 | kivertsi
# Processing Record 35 of Set 11 | uruzgan
# Processing Record 36 of Set 11 | taybad
# Processing Record 37 of Set 11 | gangtok
# Processing Record 38 of Set 11 | zolnoye
# City not found. Skipping...
# Processing Record 39 of Set 11 | pandamatenga
# Processing Record 40 of Set 11 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | pont-a-mousson
# Processing Record 42 of Set 11 | sinnamary
# Processing Record 43 of Set 11 | saint-georges
# Processing Record 44 of Set 11 | ponta delgada
# Processing Record 45 of Set 11 | bridlington
# Processing Record 46 of Set 11 | la maddalena
# Processing Record 47 of Set 11 | yanam
# Processing Record 48 of Set 11 | ede
# Processing Record 49 of Set 11 | la romana
# Processing Record 50 of Set 11 | nanortalik
# Processing Record 1 of Set 12 | sistranda
# Processing Record 2 of Set 12 | annau
# Processing Record 3 of Set 12 | zhezkazgan
# Processing Record 4 of Set 12 | villaviciosa
# Processing Record 5 of Set 12 | senno
# Processing Record 6 of Set 12 | huarmey
# Processing Record 7 of Set 12 | bonavista
# Processing Record 8 of Set 12 | loukhi
# Processing Record 9 of Set 12 | nuevitas
# Processing Record 10 of Set 12 | oriximina
# Processing Record 11 of Set 12 | kautokeino
# Processing Record 12 of Set 12 | touros
# Processing Record 13 of Set 12 | yining
# Processing Record 14 of Set 12 | punjai puliyampatti
# Processing Record 15 of Set 12 | mangrol
# Processing Record 16 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 17 of Set 12 | ust-tarka
# Processing Record 18 of Set 12 | ejura
# Processing Record 19 of Set 12 | sabha
# Processing Record 20 of Set 12 | itabirito
# Processing Record 21 of Set 12 | weston
# Processing Record 22 of Set 12 | medea
# Processing Record 23 of Set 12 | jazzin
# City not found. Skipping...
# Processing Record 24 of Set 12 | matara
# Processing Record 25 of Set 12 | gamba
# Processing Record 26 of Set 12 | pregradnoye
# Processing Record 27 of Set 12 | pychas
# Processing Record 28 of Set 12 | gwadar
# Processing Record 29 of Set 12 | oranjemund
# Processing Record 30 of Set 12 | jardim
# Processing Record 31 of Set 12 | fereydun kenar
# Processing Record 32 of Set 12 | sao francisco
# Processing Record 33 of Set 12 | tornio
# Processing Record 34 of Set 12 | pershotravneve
# Processing Record 35 of Set 12 | bahia honda
# Processing Record 36 of Set 12 | panama city
# Processing Record 37 of Set 12 | orje
# Processing Record 38 of Set 12 | temuco
# Processing Record 39 of Set 12 | maltahohe
# Processing Record 40 of Set 12 | duzici
# City not found. Skipping...
# Processing Record 41 of Set 12 | beisfjord
# Processing Record 42 of Set 12 | reftinskiy
# Processing Record 43 of Set 12 | yalta
# Processing Record 44 of Set 12 | alexandria
# Processing Record 45 of Set 12 | quibor
# Processing Record 46 of Set 12 | juba
# Processing Record 47 of Set 12 | santa maria
# Processing Record 48 of Set 12 | barahona
# Processing Record 49 of Set 12 | san ramon
# Processing Record 50 of Set 12 | port blair
# Processing Record 1 of Set 13 | abu dhabi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 550

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas -53.1500  -70.9167     51.91        46          75
# 1  Mar Del Plata -38.0023  -57.5575     66.22        80          75
# 2         Agadez  19.7500   10.2500     91.94        14           1
# 3       Hermanus -34.4187   19.2345     58.80        77           1
# 4      Bialogard  54.0070   15.9875     60.75        63          92
# 5        Ushuaia -54.8000  -68.3000     49.66        46          75
# 6    East London -33.0153   27.9116     66.60        79          86
# 7          Bayan  46.0833  127.4000     31.50        44           0
# 8           Asfi  32.2994   -9.2372     73.98        65         100
# 9      Mahebourg -20.4081   57.7000     71.89        73          40
#
#    Wind Speed Country Current Description
# 0       12.66      CL       broken clouds
# 1       11.50      AR       broken clouds
# 2        6.80      NE           clear sky
# 3       11.43      ZA           clear sky
# 4        9.40      PL     overcast clouds
# 5        9.22      AR       broken clouds
# 6        9.22      ZA     overcast clouds
# 7        4.94      CN           clear sky
# 8       18.48      MA     overcast clouds
# 9        9.22      MU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columns=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[columns]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     51.91        46          75
# 1  Mar Del Plata      AR -38.0023  -57.5575     66.22        80          75
# 2         Agadez      NE  19.7500   10.2500     91.94        14           1
# 3       Hermanus      ZA -34.4187   19.2345     58.80        77           1
# 4      Bialogard      PL  54.0070   15.9875     60.75        63          92
# 5        Ushuaia      AR -54.8000  -68.3000     49.66        46          75
# 6    East London      ZA -33.0153   27.9116     66.60        79          86
# 7          Bayan      CN  46.0833  127.4000     31.50        44           0
# 8           Asfi      MA  32.2994   -9.2372     73.98        65         100
# 9      Mahebourg      MU -20.4081   57.7000     71.89        73          40
#
#    Wind Speed Current Description
# 0       12.66       broken clouds
# 1       11.50       broken clouds
# 2        6.80           clear sky
# 3       11.43           clear sky
# 4        9.40     overcast clouds
# 5        9.22       broken clouds
# 6        9.22     overcast clouds
# 7        4.94           clear sky
# 8       18.48     overcast clouds
# 9        9.22    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
out_put_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(out_put_file, index_label="City_ID")
