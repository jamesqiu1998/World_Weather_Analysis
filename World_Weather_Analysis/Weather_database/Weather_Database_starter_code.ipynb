# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-90.000,high=90.000,size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 585

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | mumford
# Processing Record 8 of Set 1 | ambilobe
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | edd
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | igarka
# Processing Record 21 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 1 | oranjestad
# Processing Record 23 of Set 1 | anuradhapura
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | oltu
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | havre-saint-pierre
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | dunda
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 1 | puerto colombia
# Processing Record 36 of Set 1 | soverato
# Processing Record 37 of Set 1 | wrentham
# Processing Record 38 of Set 1 | vagur
# Processing Record 39 of Set 1 | dogondoutchi
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | grand gaube
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | gamba
# Processing Record 45 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | mecca
# Processing Record 50 of Set 1 | yarada
# Processing Record 1 of Set 2 | micheweni
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | sarkand
# Processing Record 4 of Set 2 | tafresh
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | tahta
# Processing Record 7 of Set 2 | tamandare
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | olafsvik
# Processing Record 13 of Set 2 | karachi
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | kadayanallur
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | santa rosa
# Processing Record 20 of Set 2 | tiznit
# Processing Record 21 of Set 2 | mitsamiouli
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | balkhash
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | vestmannaeyjar
# Processing Record 26 of Set 2 | pangnirtung
# Processing Record 27 of Set 2 | emba
# Processing Record 28 of Set 2 | unye
# City not found. Skipping...
# Processing Record 29 of Set 2 | salalah
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | kumluca
# Processing Record 32 of Set 2 | marsh harbour
# Processing Record 33 of Set 2 | kajaani
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | varzea grande
# Processing Record 37 of Set 2 | saint anthony
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | henties bay
# Processing Record 40 of Set 2 | carutapera
# Processing Record 41 of Set 2 | bilma
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | dawson
# Processing Record 44 of Set 2 | brae
# Processing Record 45 of Set 2 | salisbury
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | san antonio
# Processing Record 49 of Set 2 | maniitsoq
# Processing Record 50 of Set 2 | saint-georges
# Processing Record 1 of Set 3 | ellisras
# Processing Record 2 of Set 3 | inirida
# Processing Record 3 of Set 3 | maragogi
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | aranos
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | vire
# Processing Record 8 of Set 3 | oksfjord
# Processing Record 9 of Set 3 | imbituba
# Processing Record 10 of Set 3 | asfi
# Processing Record 11 of Set 3 | taoudenni
# Processing Record 12 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 3 | busselton
# Processing Record 14 of Set 3 | saint-pierre
# Processing Record 15 of Set 3 | sarakhs
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | aljezur
# Processing Record 18 of Set 3 | andilamena
# Processing Record 19 of Set 3 | kabompo
# Processing Record 20 of Set 3 | shubarshi
# Processing Record 21 of Set 3 | vengerovo
# Processing Record 22 of Set 3 | cobija
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | luanda
# Processing Record 25 of Set 3 | saquena
# Processing Record 26 of Set 3 | portpatrick
# City not found. Skipping...
# Processing Record 27 of Set 3 | verkh-chebula
# Processing Record 28 of Set 3 | san ramon de la nueva oran
# Processing Record 29 of Set 3 | pozhva
# Processing Record 30 of Set 3 | mizdah
# Processing Record 31 of Set 3 | bonaventure
# Processing Record 32 of Set 3 | najran
# Processing Record 33 of Set 3 | sheffield
# Processing Record 34 of Set 3 | brandfort
# Processing Record 35 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 3 | gazanjyk
# Processing Record 37 of Set 3 | nagapattinam
# Processing Record 38 of Set 3 | alibunar
# Processing Record 39 of Set 3 | tsabong
# Processing Record 40 of Set 3 | mehamn
# Processing Record 41 of Set 3 | quatre cocos
# Processing Record 42 of Set 3 | umm lajj
# Processing Record 43 of Set 3 | riberalta
# Processing Record 44 of Set 3 | korla
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | leh
# Processing Record 47 of Set 3 | ponta delgada
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | namibe
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | howell
# Processing Record 2 of Set 4 | sechura
# Processing Record 3 of Set 4 | westport
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | paranaiba
# Processing Record 6 of Set 4 | elat
# Processing Record 7 of Set 4 | port hawkesbury
# Processing Record 8 of Set 4 | krivosheino
# Processing Record 9 of Set 4 | belem de sao francisco
# Processing Record 10 of Set 4 | creutzwald
# Processing Record 11 of Set 4 | resen
# Processing Record 12 of Set 4 | kantunilkin
# Processing Record 13 of Set 4 | springdale
# Processing Record 14 of Set 4 | muniz freire
# Processing Record 15 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 4 | puerto baquerizo moreno
# Processing Record 17 of Set 4 | kunashak
# Processing Record 18 of Set 4 | port-cartier
# Processing Record 19 of Set 4 | lodwar
# Processing Record 20 of Set 4 | abu samrah
# Processing Record 21 of Set 4 | puerto narino
# Processing Record 22 of Set 4 | north adams
# Processing Record 23 of Set 4 | jalu
# Processing Record 24 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 4 | awbari
# Processing Record 26 of Set 4 | atar
# Processing Record 27 of Set 4 | roald
# Processing Record 28 of Set 4 | richards bay
# Processing Record 29 of Set 4 | acarau
# Processing Record 30 of Set 4 | faya
# Processing Record 31 of Set 4 | jacareacanga
# Processing Record 32 of Set 4 | tabory
# Processing Record 33 of Set 4 | chelmza
# Processing Record 34 of Set 4 | axim
# Processing Record 35 of Set 4 | la roda
# Processing Record 36 of Set 4 | contamana
# Processing Record 37 of Set 4 | kozhevnikovo
# Processing Record 38 of Set 4 | joshimath
# Processing Record 39 of Set 4 | akdepe
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 42 of Set 4 | kudahuvadhoo
# Processing Record 43 of Set 4 | patacamaya
# Processing Record 44 of Set 4 | diego de almagro
# Processing Record 45 of Set 4 | diffa
# Processing Record 46 of Set 4 | jimma
# Processing Record 47 of Set 4 | palmas bellas
# Processing Record 48 of Set 4 | parauna
# Processing Record 49 of Set 4 | kannangad
# Processing Record 50 of Set 4 | laon
# Processing Record 1 of Set 5 | mingaora
# Processing Record 2 of Set 5 | zhezkazgan
# Processing Record 3 of Set 5 | pitimbu
# Processing Record 4 of Set 5 | tornio
# Processing Record 5 of Set 5 | wagar
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | santiago de cao
# Processing Record 8 of Set 5 | guanica
# Processing Record 9 of Set 5 | ballina
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | oum hadjer
# Processing Record 13 of Set 5 | viedma
# Processing Record 14 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 5 | kamennomostskiy
# Processing Record 16 of Set 5 | itaobim
# Processing Record 17 of Set 5 | huarmey
# Processing Record 18 of Set 5 | bingen
# Processing Record 19 of Set 5 | birjand
# Processing Record 20 of Set 5 | muros
# Processing Record 21 of Set 5 | sorland
# Processing Record 22 of Set 5 | omboue
# Processing Record 23 of Set 5 | nizhniy baskunchak
# Processing Record 24 of Set 5 | codajas
# Processing Record 25 of Set 5 | mahon
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | baneh
# Processing Record 28 of Set 5 | svetlogorsk
# Processing Record 29 of Set 5 | mocuba
# Processing Record 30 of Set 5 | umm kaddadah
# Processing Record 31 of Set 5 | sao joao dos patos
# Processing Record 32 of Set 5 | laguna
# Processing Record 33 of Set 5 | okulovka
# Processing Record 34 of Set 5 | san rafael
# Processing Record 35 of Set 5 | zonguldak
# Processing Record 36 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 5 | tessalit
# Processing Record 38 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 39 of Set 5 | sakaraha
# Processing Record 40 of Set 5 | hobyo
# Processing Record 41 of Set 5 | osorno
# Processing Record 42 of Set 5 | lokoja
# Processing Record 43 of Set 5 | teguise
# Processing Record 44 of Set 5 | lod
# Processing Record 45 of Set 5 | zaysan
# Processing Record 46 of Set 5 | antalaha
# Processing Record 47 of Set 5 | kjopsvik
# Processing Record 48 of Set 5 | pueblo bello
# Processing Record 49 of Set 5 | nurpur
# Processing Record 50 of Set 5 | santa maria do suacui
# Processing Record 1 of Set 6 | chernolesskoye
# Processing Record 2 of Set 6 | rawson
# Processing Record 3 of Set 6 | trelew
# Processing Record 4 of Set 6 | daman
# Processing Record 5 of Set 6 | kotido
# Processing Record 6 of Set 6 | masuguru
# Processing Record 7 of Set 6 | lixourion
# Processing Record 8 of Set 6 | naryan-mar
# Processing Record 9 of Set 6 | makat
# Processing Record 10 of Set 6 | puerto el triunfo
# Processing Record 11 of Set 6 | mosquera
# Processing Record 12 of Set 6 | shirochanka
# Processing Record 13 of Set 6 | aripuana
# Processing Record 14 of Set 6 | nioro
# Processing Record 15 of Set 6 | alanya
# Processing Record 16 of Set 6 | porto velho
# Processing Record 17 of Set 6 | tucupita
# Processing Record 18 of Set 6 | svetlyy
# Processing Record 19 of Set 6 | pankovka
# Processing Record 20 of Set 6 | were ilu
# Processing Record 21 of Set 6 | sikonge
# Processing Record 22 of Set 6 | berlevag
# Processing Record 23 of Set 6 | sinnamary
# Processing Record 24 of Set 6 | proletariy
# Processing Record 25 of Set 6 | grand-santi
# Processing Record 26 of Set 6 | boma
# Processing Record 27 of Set 6 | bara
# Processing Record 28 of Set 6 | miranda
# Processing Record 29 of Set 6 | cozumel
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | richmond
# Processing Record 32 of Set 6 | toritama
# Processing Record 33 of Set 6 | moose factory
# Processing Record 34 of Set 6 | fereydun kenar
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | sherbakul
# Processing Record 37 of Set 6 | dudinka
# Processing Record 38 of Set 6 | stare mesto
# Processing Record 39 of Set 6 | iberia
# Processing Record 40 of Set 6 | aksarayskiy
# Processing Record 41 of Set 6 | sabha
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | zhmerynka
# Processing Record 44 of Set 6 | filadelfia
# Processing Record 45 of Set 6 | savannah bight
# Processing Record 46 of Set 6 | ratnagiri
# Processing Record 47 of Set 6 | barreirinha
# Processing Record 48 of Set 6 | stephenville crossing
# Processing Record 49 of Set 6 | cockburn town
# Processing Record 50 of Set 6 | hauterive
# Processing Record 1 of Set 7 | ouranopolis
# City not found. Skipping...
# Processing Record 2 of Set 7 | talaja
# Processing Record 3 of Set 7 | jutai
# Processing Record 4 of Set 7 | malatya
# Processing Record 5 of Set 7 | husavik
# Processing Record 6 of Set 7 | talara
# Processing Record 7 of Set 7 | vigrestad
# Processing Record 8 of Set 7 | iquitos
# Processing Record 9 of Set 7 | belyy yar
# Processing Record 10 of Set 7 | havoysund
# Processing Record 11 of Set 7 | centralia
# Processing Record 12 of Set 7 | at-bashi
# Processing Record 13 of Set 7 | sorkjosen
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 16 of Set 7 | chapais
# Processing Record 17 of Set 7 | japura
# Processing Record 18 of Set 7 | sawakin
# Processing Record 19 of Set 7 | port-de-bouc
# Processing Record 20 of Set 7 | walvis bay
# Processing Record 21 of Set 7 | paarl
# Processing Record 22 of Set 7 | carnarvon
# Processing Record 23 of Set 7 | mangalam
# Processing Record 24 of Set 7 | rocha
# Processing Record 25 of Set 7 | jujuy
# City not found. Skipping...
# Processing Record 26 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 27 of Set 7 | kindu
# Processing Record 28 of Set 7 | winchester
# Processing Record 29 of Set 7 | garoua boulai
# Processing Record 30 of Set 7 | kose
# Processing Record 31 of Set 7 | tel aviv-yafo
# Processing Record 32 of Set 7 | bubaque
# Processing Record 33 of Set 7 | le port
# Processing Record 34 of Set 7 | san francisco
# Processing Record 35 of Set 7 | belomorsk
# Processing Record 36 of Set 7 | belmonte
# Processing Record 37 of Set 7 | thinadhoo
# Processing Record 38 of Set 7 | dinguiraye
# Processing Record 39 of Set 7 | lethem
# Processing Record 40 of Set 7 | ierapetra
# Processing Record 41 of Set 7 | macedo de cavaleiros
# Processing Record 42 of Set 7 | royan
# Processing Record 43 of Set 7 | upata
# Processing Record 44 of Set 7 | trzebiatow
# Processing Record 45 of Set 7 | novyye burasy
# Processing Record 46 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 7 | pescia
# Processing Record 48 of Set 7 | sakakah
# Processing Record 49 of Set 7 | palaikastron
# Processing Record 50 of Set 7 | boysun
# Processing Record 1 of Set 8 | choma
# Processing Record 2 of Set 8 | coihaique
# Processing Record 3 of Set 8 | cumana
# Processing Record 4 of Set 8 | tabriz
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | tarime
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | goure
# Processing Record 9 of Set 8 | kattivakkam
# Processing Record 10 of Set 8 | iskateley
# Processing Record 11 of Set 8 | kifri
# Processing Record 12 of Set 8 | morondava
# Processing Record 13 of Set 8 | sundumbili
# Processing Record 14 of Set 8 | strezhevoy
# Processing Record 15 of Set 8 | san ramon
# Processing Record 16 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 17 of Set 8 | mabaruma
# Processing Record 18 of Set 8 | ylojarvi
# Processing Record 19 of Set 8 | dalbandin
# Processing Record 20 of Set 8 | oriximina
# Processing Record 21 of Set 8 | aromashevo
# Processing Record 22 of Set 8 | nosy varika
# Processing Record 23 of Set 8 | khorixas
# Processing Record 24 of Set 8 | kargat
# Processing Record 25 of Set 8 | nalut
# Processing Record 26 of Set 8 | tamale
# Processing Record 27 of Set 8 | buraydah
# Processing Record 28 of Set 8 | poli
# Processing Record 29 of Set 8 | fevik
# Processing Record 30 of Set 8 | paoua
# Processing Record 31 of Set 8 | willowmore
# Processing Record 32 of Set 8 | rovaniemi
# Processing Record 33 of Set 8 | paracuru
# Processing Record 34 of Set 8 | laranjal paulista
# Processing Record 35 of Set 8 | mendoza
# Processing Record 36 of Set 8 | souillac
# Processing Record 37 of Set 8 | valdivia
# Processing Record 38 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 8 | ribeira brava
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | cremona
# Processing Record 42 of Set 8 | sesheke
# Processing Record 43 of Set 8 | golfito
# Processing Record 44 of Set 8 | kilindoni
# Processing Record 45 of Set 8 | garowe
# Processing Record 46 of Set 8 | basoko
# Processing Record 47 of Set 8 | peniche
# Processing Record 48 of Set 8 | stornoway
# Processing Record 49 of Set 8 | holguin
# Processing Record 50 of Set 8 | nuuk
# Processing Record 1 of Set 9 | niquero
# Processing Record 2 of Set 9 | atlantic beach
# Processing Record 3 of Set 9 | pokhara
# Processing Record 4 of Set 9 | isiro
# Processing Record 5 of Set 9 | anloga
# Processing Record 6 of Set 9 | nouadhibou
# Processing Record 7 of Set 9 | fonte boa
# Processing Record 8 of Set 9 | kutum
# Processing Record 9 of Set 9 | san julian
# Processing Record 10 of Set 9 | rio gallegos
# Processing Record 11 of Set 9 | luebo
# Processing Record 12 of Set 9 | grindavik
# Processing Record 13 of Set 9 | sezana
# Processing Record 14 of Set 9 | san luis
# Processing Record 15 of Set 9 | minsk
# Processing Record 16 of Set 9 | lubango
# Processing Record 17 of Set 9 | luangwa
# Processing Record 18 of Set 9 | formosa
# Processing Record 19 of Set 9 | saint-augustin
# Processing Record 20 of Set 9 | barcelos
# Processing Record 21 of Set 9 | comodoro rivadavia
# Processing Record 22 of Set 9 | ostersund
# Processing Record 23 of Set 9 | abalak
# Processing Record 24 of Set 9 | yining
# Processing Record 25 of Set 9 | serra talhada
# Processing Record 26 of Set 9 | piney green
# Processing Record 27 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 9 | kabinda
# Processing Record 29 of Set 9 | carndonagh
# Processing Record 30 of Set 9 | picos
# Processing Record 31 of Set 9 | kita
# Processing Record 32 of Set 9 | mutare
# Processing Record 33 of Set 9 | amapa
# Processing Record 34 of Set 9 | kabwe
# Processing Record 35 of Set 9 | urucara
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | pauini
# Processing Record 38 of Set 9 | puerto rondon
# Processing Record 39 of Set 9 | mitu
# Processing Record 40 of Set 9 | burica
# City not found. Skipping...
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 9 | saint-joseph
# Processing Record 44 of Set 9 | ngama
# Processing Record 45 of Set 9 | virginia beach
# Processing Record 46 of Set 9 | kapuskasing
# Processing Record 47 of Set 9 | caravelas
# Processing Record 48 of Set 9 | tete
# Processing Record 49 of Set 9 | port-gentil
# Processing Record 50 of Set 9 | susangerd
# Processing Record 1 of Set 10 | warrington
# Processing Record 2 of Set 10 | kipini
# Processing Record 3 of Set 10 | neuquen
# Processing Record 4 of Set 10 | aksarka
# Processing Record 5 of Set 10 | ornskoldsvik
# Processing Record 6 of Set 10 | sal rei
# Processing Record 7 of Set 10 | hamilton
# Processing Record 8 of Set 10 | yendi
# Processing Record 9 of Set 10 | bandarbeyla
# Processing Record 10 of Set 10 | polyarnyy
# Processing Record 11 of Set 10 | sohbatpur
# Processing Record 12 of Set 10 | saint-leu
# Processing Record 13 of Set 10 | touros
# Processing Record 14 of Set 10 | camacupa
# Processing Record 15 of Set 10 | pachmarhi
# Processing Record 16 of Set 10 | visby
# Processing Record 17 of Set 10 | vossevangen
# Processing Record 18 of Set 10 | bhigvan
# Processing Record 19 of Set 10 | turukhansk
# Processing Record 20 of Set 10 | marzuq
# Processing Record 21 of Set 10 | jumla
# Processing Record 22 of Set 10 | ibatiba
# Processing Record 23 of Set 10 | krutikha
# Processing Record 24 of Set 10 | mariel
# Processing Record 25 of Set 10 | yumbel
# Processing Record 26 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 10 | demidov
# Processing Record 28 of Set 10 | benin
# Processing Record 29 of Set 10 | la romana
# Processing Record 30 of Set 10 | camacha
# Processing Record 31 of Set 10 | kharp
# Processing Record 32 of Set 10 | arnissa
# Processing Record 33 of Set 10 | mortka
# Processing Record 34 of Set 10 | dagana
# Processing Record 35 of Set 10 | panaba
# Processing Record 36 of Set 10 | fagernes
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | nepa nagar
# Processing Record 39 of Set 10 | kashi
# Processing Record 40 of Set 10 | karema
# Processing Record 41 of Set 10 | vilhena
# Processing Record 42 of Set 10 | vilcun
# Processing Record 43 of Set 10 | miquelon
# Processing Record 44 of Set 10 | tutoia
# Processing Record 45 of Set 10 | chacabuco
# Processing Record 46 of Set 10 | samfya
# Processing Record 47 of Set 10 | araouane
# Processing Record 48 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 10 | albenga
# Processing Record 50 of Set 10 | nizhneivkino
# Processing Record 1 of Set 11 | sayyan
# Processing Record 2 of Set 11 | bomet
# Processing Record 3 of Set 11 | teguldet
# Processing Record 4 of Set 11 | mariana
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | agara
# Processing Record 7 of Set 11 | sosnovoborsk
# Processing Record 8 of Set 11 | ferme-neuve
# Processing Record 9 of Set 11 | maceio
# Processing Record 10 of Set 11 | salinopolis
# Processing Record 11 of Set 11 | agadez
# Processing Record 12 of Set 11 | san javier
# Processing Record 13 of Set 11 | paamiut
# Processing Record 14 of Set 11 | lipin bor
# Processing Record 15 of Set 11 | esmeraldas
# Processing Record 16 of Set 11 | arnoldstein
# Processing Record 17 of Set 11 | vladesti
# Processing Record 18 of Set 11 | jibuti
# Processing Record 19 of Set 11 | bhadrapur
# Processing Record 20 of Set 11 | tabou
# Processing Record 21 of Set 11 | korablino
# Processing Record 22 of Set 11 | abonnema
# Processing Record 23 of Set 11 | monrovia
# Processing Record 24 of Set 11 | ajdabiya
# Processing Record 25 of Set 11 | waddan
# Processing Record 26 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 27 of Set 11 | presidente dutra
# Processing Record 28 of Set 11 | lunino
# Processing Record 29 of Set 11 | chamalieres
# Processing Record 30 of Set 11 | severnyy
# Processing Record 31 of Set 11 | shache
# Processing Record 32 of Set 11 | cheremukhovo
# Processing Record 33 of Set 11 | nara
# Processing Record 34 of Set 11 | paralimni
# Processing Record 35 of Set 11 | marawi
# Processing Record 36 of Set 11 | aden
# Processing Record 37 of Set 11 | arlit
# Processing Record 38 of Set 11 | am timan
# Processing Record 39 of Set 11 | mglin
# Processing Record 40 of Set 11 | gornyak
# Processing Record 41 of Set 11 | mombaca
# Processing Record 42 of Set 11 | sao lourenco do oeste
# Processing Record 43 of Set 11 | tingo maria
# Processing Record 44 of Set 11 | matara
# Processing Record 45 of Set 11 | fort payne
# Processing Record 46 of Set 11 | narkevychi
# Processing Record 47 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 48 of Set 11 | bossangoa
# Processing Record 49 of Set 11 | anzio
# Processing Record 50 of Set 11 | oistins
# Processing Record 1 of Set 12 | scarborough
# Processing Record 2 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 12 | shakawe
# Processing Record 4 of Set 12 | riyadh
# Processing Record 5 of Set 12 | bama
# Processing Record 6 of Set 12 | puerto leguizamo
# Processing Record 7 of Set 12 | pundri
# Processing Record 8 of Set 12 | bengkulu
# Processing Record 9 of Set 12 | itarema
# Processing Record 10 of Set 12 | irtyshskiy
# Processing Record 11 of Set 12 | chinchani
# Processing Record 12 of Set 12 | auch
# Processing Record 13 of Set 12 | patitirion
# Processing Record 14 of Set 12 | trinidad
# Processing Record 15 of Set 12 | jega
# Processing Record 16 of Set 12 | una
# Processing Record 17 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 12 | hurghada
# Processing Record 19 of Set 12 | quelimane
# Processing Record 20 of Set 12 | moreira sales
# Processing Record 21 of Set 12 | sovetskiy
# Processing Record 22 of Set 12 | mgandu
# Processing Record 23 of Set 12 | sistranda
# Processing Record 24 of Set 12 | hualmay
# Processing Record 25 of Set 12 | valday
# Processing Record 26 of Set 12 | aguimes
# Processing Record 27 of Set 12 | conceicao do araguaia
# Processing Record 28 of Set 12 | praia
# Processing Record 29 of Set 12 | sao jose da coroa grande
# Processing Record 30 of Set 12 | pedernales
# Processing Record 31 of Set 12 | jales
# Processing Record 32 of Set 12 | oberndorf
# Processing Record 33 of Set 12 | roquetas de mar
# Processing Record 34 of Set 12 | itacare
# Processing Record 35 of Set 12 | sept-iles
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 546

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Clyde River  70.4692 -68.5914     26.83        74         100       19.57
# 1      Ushuaia -54.8000 -68.3000     49.66        46          75        9.22
# 2     Hermanus -34.4187  19.2345     60.80        77           1       11.43
# 3       Dikson  73.5069  80.5464     31.12        69         100        1.36
# 4    Hithadhoo  -0.6000  73.0833     82.74        74          94       17.40
# 5      Iqaluit  63.7506 -68.5145     33.53        93         100        4.61
# 6      Mumford   5.2618  -0.7590     78.28        83          38       12.39
# 7     Ambilobe -13.2000  49.0500     72.64        76           5        2.17
# 8         Chuy -33.6971 -53.4616     67.93        54          36       14.23
# 9          Edd  13.9297  41.6925     89.47        64          52       11.74
#
#   Country Current Description
# 0      CA     overcast clouds
# 1      AR       broken clouds
# 2      ZA           clear sky
# 3      RU     overcast clouds
# 4      MV     overcast clouds
# 5      CA          light snow
# 6      GH    scattered clouds
# 7      MG           clear sky
# 8      UY    scattered clouds
# 9      ER       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columns=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[columns]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Clyde River      CA  70.4692 -68.5914     26.83        74         100
# 1      Ushuaia      AR -54.8000 -68.3000     49.66        46          75
# 2     Hermanus      ZA -34.4187  19.2345     60.80        77           1
# 3       Dikson      RU  73.5069  80.5464     31.12        69         100
# 4    Hithadhoo      MV  -0.6000  73.0833     82.74        74          94
# 5      Iqaluit      CA  63.7506 -68.5145     33.53        93         100
# 6      Mumford      GH   5.2618  -0.7590     78.28        83          38
# 7     Ambilobe      MG -13.2000  49.0500     72.64        76           5
# 8         Chuy      UY -33.6971 -53.4616     67.93        54          36
# 9          Edd      ER  13.9297  41.6925     89.47        64          52
#
#    Wind Speed Current Description
# 0       19.57     overcast clouds
# 1        9.22       broken clouds
# 2       11.43           clear sky
# 3        1.36     overcast clouds
# 4       17.40     overcast clouds
# 5        4.61          light snow
# 6       12.39    scattered clouds
# 7        2.17           clear sky
# 8       14.23    scattered clouds
# 9       11.74       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
out_put_file = "Weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(out_put_file, index_label='City_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17168\490881032.py in <module>
#       3
#       4 # Export the city_data DataFrame into a CSV file
# ----> 5 city_data_df.to_csv(out_put_file, index_label='City_ID')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_database/WeatherPy_Database.csv'
